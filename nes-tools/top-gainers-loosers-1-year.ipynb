# %%
from nsetools import Nse
import pandas as pd
from datetime import datetime, timedelta

nse = Nse()

# Define the date range
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=365)).strftime('%Y-%m-%d')

# Get top gainers and losers
top_gainers = nse.get_top_gainers()
top_losers = nse.get_top_losers()

# Convert to DataFrame
gainers_df = pd.DataFrame(top_gainers)
losers_df = pd.DataFrame(top_losers)

# Save to CSV
gainers_df.to_csv('top_gainers.csv', index=False)
losers_df.to_csv('top_losers.csv', index=False)

print("Data downloaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9 start_date = (datetime.today() - timedelta(days=365)).strftime('%Y-%m-%d')
#      11 # Get top gainers and losers
# ---> 12 top_gainers = nse.get_top_gainers()
#      13 top_losers = nse.get_top_losers()
#      15 # Convert to DataFrame
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nsetools\nse.py:190, in Nse.get_top_gainers(self, as_json)
#     188 req = Request(url, None, self.headers)
#     189 # this can raise HTTPError and URLError
# --> 190 res = self.opener.open(req)
#     191 # for py3 compat covert byte file like object to
#     192 # string file like object
#     193 res = byte_adaptor(res)
#
# File c:\ProgramData\Anaconda3\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# NSE top gainers URL
gainers_url = "https://www.nseindia.com/market-data/top-gainers"
losers_url = "https://www.nseindia.com/market-data/top-losers"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# Fetch and parse data
response_gainers = requests.get(gainers_url, headers=headers)
response_losers = requests.get(losers_url, headers=headers)

soup_gainers = BeautifulSoup(response_gainers.content, "html.parser")
soup_losers = BeautifulSoup(response_losers.content, "html.parser")

# Extract data (this will depend on the actual HTML structure of the page)
gainers_data = []  # You will need to parse the specific tags
losers_data = []  # You will need to parse the specific tags

# Convert to DataFrame and save to CSV
gainers_df = pd.DataFrame(gainers_data)
losers_df = pd.DataFrame(losers_data)

gainers_df.to_csv('top_gainers.csv', index=False)
losers_df.to_csv('top_losers.csv', index=False)

print("Data saved to CSV files.")
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# ...
